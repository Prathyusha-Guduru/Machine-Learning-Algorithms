# %% [markdown]
# # ASSIGNMENT - 3 - MACHINE LEARNING LAB
# ### NAME - PULKIT JASTI
# ### ROLL NUMBER - AP19110010491
# ### CSE - C

# %% [markdown]
# Import the Iris dataset. Write a program to obtain the (i) Euclidean distance, (ii) Manhattan
# Distance, and (iii) Minkowski distance Matrices for all the data samples in the feature space.
# Distance matrix is a 2D array, where the (i,j) th entry represents the distance between the i th and
# j th sample points in the feature space.

# %%
import numpy as np 
import math 
from scipy.spatial import distance 
def euclidean_dist(x,y): 
	sume = 0 
	# for i in range(len(x)): 
	sume += ((x-y)**2) 
	return sume ** (1/2)

# %%
def manhattan_dist(x,y): 
	summ = 0 
	summ += abs(x - y) 
	return summ

# %%
def Minkowski_dist(x,y,p): 
    sumMi = 0 
    sumMi += (abs(x - y))**p 
    return sumMi**(1/p)

# %%
import pandas as pd 
from sklearn import datasets 
iris_dataset = datasets.load_iris() 
iris_dataset.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris = pd.DataFrame(iris_dataset.data, 
columns=iris_dataset.feature_names) 
iris["species"] = iris_dataset.target 
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
np_iris= iris.to_numpy() 
np_iris
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ],
#        [5.4, 3.9, 1.7, 0.4, 0. ],
#        [4.6, 3.4, 1.4, 0.3, 0. ],
#        [5. , 3.4, 1.5, 0.2, 0. ],
#        [4.4, 2.9, 1.4, 0.2, 0. ],
#        [4.9, 3.1, 1.5, 0.1, 0. ],
#        [5.4, 3.7, 1.5, 0.2, 0. ],
#        [4.8, 3.4, 1.6, 0.2, 0. ],
#        [4.8, 3. , 1.4, 0.1, 0. ],
#        [4.3, 3. , 1.1, 0.1, 0. ],
#        [5.8, 4. , 1.2, 0.2, 0. ],
#        [5.7, 4.4, 1.5, 0.4, 0. ],
#        [5.4, 3.9, 1.3, 0.4, 0. ],
#        [5.1, 3.5, 1.4, 0.3, 0. ],
#        [5.7, 3.8, 1.7, 0.3, 0. ],
#        [5.1, 3.8, 1.5, 0.3, 0. ],
#        [5.4, 3.4, 1.7, 0.2, 0. ],
#        [5.1, 3.7, 1.5, 0.4, 0. ],
#        [4.6, 3.6, 1. , 0.2, 0. ],
#        [5.1, 3.3, 1.7, 0.5, 0. ],
#        [4.8, 3.4, 1.9, 0.2, 0. ],
#        [5. , 3. , 1.6, 0.2, 0. ],
#        [5. , 3.4, 1.6, 0.4, 0. ],
# ...

# %%
distance_list = [] 
for x in np_iris: 
	for y in x: 
		distance = euclidean_dist(x,y) 
		distance_list.append(distance)
# print(len(distance_list))
print("Euclidean distance for IRIS DATASET: ") 
print(distance_list)
# Out:
# Euclidean distance for IRIS DATASET:
# ...

# %%
distance_list2 = [] 
for x in np_iris: 
	for y in x: 
		distance = Minkowski_dist(x,y,3) 
		distance_list2.append(distance)
print("Minikowski distance of IRIS DATASET: ")
print(distance_list2)
# Out:
# Minikowski distance of IRIS DATASET:
# ...

# %%
distance_list3 = [] 
for x in np_iris: 
	for y in x: 
		distance = manhattan_dist(x,y) 
		distance_list3.append(distance)
print("Manhattan distance of IRIS DATASET: ")
print(distance_list3)
# Out:
# Manhattan distance of IRIS DATASET:
# ...
